# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
Exp = pickle.load(open("E:/Uni Freiburg/Scripts and study material/SoSe 19/Auto ML/Coding Excercises/master/ex09/src/data/exp.pkl","rb"))
true_r = pickle.load(open("E:/Uni Freiburg/Scripts and study material/SoSe 19/Auto ML/Coding Excercises/master/ex09/src/data/tru.pkl","rb"))


fig = plt.figure()
fig.suptitle('True vs expected reward @ learning rate=1.125 & discount factor =0.49')
plt.plot(Exp, label='Expected Reward')
plt.xlabel('No of episodes')
plt.plot(true_r, label='True Reward')
plt.ylabel('Reward')
plt.legend(frameon=False)
plt.show()
